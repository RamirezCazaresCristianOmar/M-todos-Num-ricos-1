# %% [markdown]
# <a href="https://colab.research.google.com/github/RamirezCazaresCristianOmar/M-todos-Num-ricos-1/blob/main/Metodo_Newton_Raphson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Método de Newton-Raphson

# %% [markdown]
# #Use el metodo de newton para determinar una solucion exacta dentro de $10^{-2}$ para $x^3-x-1=0$ en [1.2].$Use P_0=1 $

# %%
from math import *
import numpy as np
import matplotlib . pyplot as plt

# %%
# Definimos la funcion original f(x)=x**3 - x - 1
def f(x):
    return x**3 - x - 1

# %% [markdown]
# #Derivamos la funcion $x^3−x−1=0$, obtenemos la funcion  $f'(x)=3x^2-1$

# %%
def df(x):  #funcion f'(x)
    return 3*x**2 - 1 #la funcion derivada

# %%
# guarda valores iniciales
P0=1
#guarda valores iniciales del error y del número de iteraciones
tol = 0.01 #tolerancia
nmax = 100 #numero maximo de iteraciones
error = 100 #nos esta dando la indicacion que el erro comienza en 100
niter = 0 #es el encargado de contar las iteraciones

# %%
#Metodo de Newton

# Ciclo iterativo de newton

# Imprime los encabezados de las columnas para mostrar la iteracion actual
print("# iter\t\t Pn \t\t f(Pn) \t\t error")

# El ciclo se ejecuta mientras el error sea mayor que la tolerancia y no se supere el número máximo de iteraciones
while error > tol and niter < nmax:

    Pn = P0 - f(P0) / df(P0)  # Evalúa de la formula de newton
    error = abs(Pn - P0)  # Calcula el error absoluto entre Pn y P0

    # Imprimir el numero de iteracion, el valor de P0, Pn y el error
    print("{0} \t\t {1:6.6f} \t {2:6.6f} \t {3:6.6f}".format(niter, P0, Pn, error))

    P0 = Pn  # Actualizamos el valor de P0 para la siguiente iteración
    niter += 1  # Incrementa el contador de iteraciones

# Imprime el resultado final, mostrando la solución aproximada y el error asociado cuando el ciclo termina
print("La solución exacta utilizando el método de Newton-Raphson en el intervalo [1,2] para P es = {0:6.6f} con un error de {1:6.6f}".format(P0, error))
# Out:
# # iter		 Pn 		 f(Pn) 		 error
# 0 		 1.000000 	 1.500000 	 0.500000
# 1 		 1.500000 	 1.347826 	 0.152174
# 2 		 1.347826 	 1.325200 	 0.022626
# 3 		 1.325200 	 1.324718 	 0.000482
# La solución exacta utilizando el método de Newton-Raphson en el intervalo [1,2] para P es = 1.324718 con un error de 0.000482

# %%
x=np.linspace(0,5,100)

# %%
#Graficamos la funcion f(x)
plt.plot(f(x), color="purple") #funcion f(x)
#Graficamos la derivacion de la funcion f(x)
plt.plot(df(x), color="blue") #factorizacion de la funcion g(x)
plt.axhline(0, color="blue")
plt.axvline(0, color="blue")
plt.xlabel('Abscisas')
plt.ylabel('Ordenadas')
plt.title('Metodo de Newton-Raphson')
plt.grid()
plt.show()
