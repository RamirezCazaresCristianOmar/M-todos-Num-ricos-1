# %% [markdown]
# <a href="https://colab.research.google.com/github/RamirezCazaresCristianOmar/M-todos-Num-ricos-1/blob/main/Librer%C3%ADa_Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
F =np.array([-5, 1, 9, 25, 55, 105])
X=np.array([0, 1, 2, 3, 4, 5,])

# %%
F
# Out:
# array([ -5,   1,   9,  25,  55, 105])

# %%
type(F)
# Out:
# numpy.ndarray

# %%
#Graficamos
plt.scatter(X,F, color="magenta",marker='o')
plt.title("Gráfica de los datos")
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(color="blue",linestyle="--")
plt.show()

# %%
def f(x):
   return x**3-2*x**2+7*x-5

x1=np.linspace(0,5,100)

# %%
plt.plot(x1, f(x1))
plt.scatter(X,F, color="purple",marker='o')
plt.title("Gráfica de los datos")
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(color="blue",linestyle="--")
plt.show()

# %%
#Definir el algoritmo
dif=F[1]-F[0]
print(dif)
# Out:
# 6

# %%
for i in range(len(F[1])-1):
   dif=F[i+1]-F[1]
print(dif)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-128955053ae4> in <cell line: 1>()
# ----> 1 for i in range(len(F[1])-1):
#       2    dif=F[i+1]-F[1]
#       3 print(dif)
#
# TypeError: object of type 'numpy.int64' has no len()

# %%
G=np.diff(F)
print(G)
# Out:
# [ 6  8 16 30 50]

# %%
G2=np.diff(G)
print(G2)
# Out:
# [ 2  8 14 20]

# %%
G3=np.diff(G2)
print(G3)
# Out:
# [6 6 6]

# %%
import scipy.special as sp

# %%
N=sp.binom(0.5,3)
print(N)
# Out:
# 0.0625
